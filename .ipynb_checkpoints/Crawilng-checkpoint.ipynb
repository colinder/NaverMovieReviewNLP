# %%
# 개인정보입니다. 유출에 신경써주세요.
###################################
Client_ID = '242yKS8t2kqS9lUEECrs'
Client_Secret = 'RyISQlAvT7'
###################################

import os
import sys
import urllib.request
import json
import pandas as pd

def url_setting(start):
    url = "https://openapi.naver.com/v1/search/" + "blog" + "?query=" + encText + "&display=100" + "&start=" + str(start)
    return url

search = input("검색할 단어를 입력해주세요 : ",)
client_id = Client_ID
client_secret = Client_Secret
encText = urllib.parse.quote(search)

# for i in range(1, 1001, 100)      # 수집의 양을 늘리기 위함.
    # url = url_setting(i) 

# 테스트를 위한 소스코드
url = url_setting(1)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

# 응답 코드를 확인
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
#     print(json.loads(result))       # <class 'dict'> / keys = dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])
    items = json.loads(result)['items']
    
    aa = pd.DataFrame(items)
    pd.set_option('display.width', 1000)

    for i, item in enumerate(items):
        print(i, item, end='\n')
# Out:
# 검색할 단어를 입력해주세요 : 영화 미나리
# 0 {'title': '<b>영화 미나리</b> 결말 해석 다시보기 방법 알아보기 주관적인 후기... ', 'link': 'https://blog.naver.com/roseess?Redirect=Log&logNo=222324320243', 'description': '<b>영화 미나리</b>를 인터넷으로 볼 수 있는 방법은 여러가지가 있는데 네이버에서 결제를 해서 볼 수도 있고... 원래는 한국어를 거의 못하는데 미나리 영화 연기를 위해 배웠다고 한다. (내가 아는 바는 그렇다) 사실... ', 'bloggername': '핫이슈매거진✔', 'bloggerlink': 'https://blog.naver.com/roseess', 'postdate': '20210427'}
# 1 {'title': '*<b>영화</b> 그 이상의 감동. 세종 CGV에서 <b>미나리</b> 감상해보기 (+가격... ', 'link': 'https://blog.naver.com/sky67014?Redirect=Log&logNo=222347060587', 'description': '끝~ #코로나영화, #코로나영화관, #코로나2단계영화, #코로나영화관거리두기, #CGV코로나, #CGV세종, #세종영화관. #<b>영화미나리</b>, #미나리줄거리, #미나리평점, #미나리내용, #<b>영화미나리</b>후기, #과거상영작... ', 'bloggername': '보통일상에 잼듬뿍♬ 오늘을ㆍ처음사는ㆍ내인생기록', 'bloggerlink': 'https://blog.naver.com/sky67014', 'postdate': '20210511'}
# 2 {'title': '[<b>영화</b>] <b>미나리</b>', 'link': 'https://blog.naver.com/viana325?Redirect=Log&logNo=222362998353', 'description': '<b>미나리</b>, 원더풀 ♬&quot; 리듬을 타는 손자. <b>영화</b> 마지막 씬, 마지막 대사가, 그 동안의 노고가 깡그리 불에 타버리고 나서 남아 있는 <b>미나리</b>를 보며 아빠가 하는 말, &quot;맛있겠다!&quot; 매우 심플하다. 그 심풀함이 이상하게... ', 'bloggername': '토닥토닥 사랑방', 'bloggerlink': 'https://blog.naver.com/viana325', 'postdate': '20210523'}
# 3 {'title': "<b>영화</b> &lt;<b>미나리</b>&gt; 희망의 불씨를 '함께' 틔우는 '가족'", 'link': 'https://blog.naver.com/teamate?Redirect=Log&logNo=222333136942', 'description': "이렇게 만난 &lt;<b>미나리</b>&gt;는 잔잔한 인생 드라마. 20대에 '<b>영화</b>는 나와 다른 타인의 삶을 들여다보고 이해할 수 있게 만드는 매체'라 생각하고 진지한 <b>영화</b>를 찾아보곤 했는데, 오랜만에 그런 <b>영화</b>를 극장에서 보는... ", 'bloggername': '배시시의 기억 보조 공간', 'bloggerlink': 'https://blog.naver.com/teamate', 'postdate': '20210502'}
# 4 {'title': '<b>영화 미나리</b> 결말 모두가 미나리다', 'link': 'https://blog.naver.com/jchzz?Redirect=Log&logNo=222347423506', 'description': '어제 한가로운 오후 텅텅 빈 영화관에 가서 <b>영화 미나리</b>를 봤어요. 미나리의 결말에 대해 포스팅을 하고 싶은 마음이 강하게 들어 작성하게 됐습니다. 더불어 줄거리도 포함해서 포스팅해봤습니다. <b>영화 미나리</b>... ', 'bloggername': "Never say 'Never'", 'bloggerlink': 'https://blog.naver.com/jchzz', 'postdate': '20210512'}
# 5 {'title': '<b>미나리</b> <b>영화</b> 윤여정 오스카 여우조연상 후보 2021 아카데미... ', 'link': 'https://blog.naver.com/ariel74?Redirect=Log&logNo=222322292673', 'description': "미나리 영화 윤여정 오스카 여우조연상 후보 2021 아카데미 시상식 시간은? 윤여정 배우님, 요즘 이분... 탤런트 <b>영화 미나리</b>에서 할머니 '순자' 역을 맡았던 윤여정 배우님은 이번 아카데미 시상식의... ", 'bloggername': '여행언니', 'bloggerlink': 'https://blog.naver.com/ariel74', 'postdate': '20210425'}
# 6 {'title': '해독작용이 뛰어난 봄철의 영양 채소 &lt;<b>미나리</b>&gt; (<b>영화</b> 아님 주의)', 'link': 'https://blog.naver.com/eyeana?Redirect=Log&logNo=222325559350', 'description': '<b>영화</b> &lt;<b>미나리</b>&gt;도 함께 추천합니다. 많은 분들이 영화 속 명대사로 평가해 주신 내용 전해드리며 마무리하겠습니다. 오늘도 행복하세요~^^ 미나리는 어디에 있어도 알아서 잘 자라고, 부자든 가난한... ', 'bloggername': '청양사자산마을 시골이야기', 'bloggerlink': 'https://blog.naver.com/eyeana', 'postdate': '20210428'}
# 7 {'title': '<b>영화</b> - <b>미나리</b> (Minari, 2020)', 'link': 'https://blog.naver.com/b922h?Redirect=Log&logNo=222343644539', 'description': '<b>미나리</b> 감독 정이삭 출연 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조, 윌 패튼 개봉 2021. 03. 03. 작년... 비록 이 <b>영화</b>는 미국 자본, 미국 감독이 만든 명실상부 미국<b>영화</b>이지만, 주인공들은 1970년대 미국으로... ', 'bloggername': '소파가 있는 풍경', 'bloggerlink': 'https://blog.naver.com/b922h', 'postdate': '20210509'}
# 8 {'title': '진주 엠비씨네 <b>영화</b>관 프라이빗 방문후기 <b>미나리</b><b>영화</b> 추천', 'link': 'https://blog.naver.com/hsh6340?Redirect=Log&logNo=222326815784', 'description': '입장합니다~~ <b>영화 미나리</b> 요즘 서복도 핫하더라구요~ 저랑 부모님은 미나리 영화가 너무 궁금하기도 하고 보고싶었던 영화라서 선택했어요 대학생 할인 대학생은 학생증이 있으면 영화 3천원 할인되어요... ', 'bloggername': '메이플라워의 일상', 'bloggerlink': 'https://blog.naver.com/hsh6340', 'postdate': '20210428'}
# 9 {'title': '[<b>영화</b>]<b>미나리</b>', 'link': 'https://blog.naver.com/kschung?Redirect=Log&logNo=222315931535', 'description': '(스포있습니다.) 뜬금없이 <b>영화 미나리</b>가 화제다. 이게 한국영화다 할리우드 영화냐에 대한 논쟁이... 찾아 미나리를 자르며 영화가 끝난다. 다른 누구보다도 나는 이 영화에서 우리 어머니의 모습을 보는 것... ', 'bloggername': '길을 걸으면 내가 보인다 Finding myself on the road', 'bloggerlink': 'https://blog.naver.com/kschung', 'postdate': '20210419'}
# 10 {'title': '아메리칸 드림을 꿈꾸다! <b>영화</b> &lt;<b>미나리</b>&gt;로 보는 이민정책', 'link': 'https://blog.naver.com/mosfnet?Redirect=Log&logNo=222345330645', 'description': '이제는 한국인 최초 아카데미 시상식 여우조연상을 배출한 <b>영화</b> &lt;<b>미나리</b>&gt;가 가장 먼저 떠오르실... <b>영화 미나리</b>에는 한국을 떠난 이민 가족들이 겪는 어려운 삶의 이야기를 고스란히 보여주고 있습니다. 우리의... ', 'bloggername': '기획재정부 경제e야기', 'bloggerlink': 'https://blog.naver.com/mosfnet', 'postdate': '20210510'}
# 11 {'title': '<b>미나리</b> <b>영화</b> 개인적인 후기', 'link': 'https://blog.naver.com/megkis?Redirect=Log&logNo=222264726649', 'description': '여하튼 미나리 영화 잔잔하니 지루하지 않게 잘 보긴 했어요 따스함이 느껴지는 가족영화! 그리고 마지막 자막에 브래드피트 이름이 보여서 의아했는데 알고보니 <b>영화 미나리</b> 브래드피트가 제작을 한거였군요... ', 'bloggername': '헝클어진 마케팅, 문지기 블로그™', 'bloggerlink': 'https://blog.naver.com/megkis', 'postdate': '20210304'}
# 12 {'title': '<b>영화 미나리</b> 2020 (미국)', 'link': 'https://blog.naver.com/seotaijiyg?Redirect=Log&logNo=222319307696', 'description': '한국 감독 정이삭 윤여정 스티븐 연 한예리 엘런 김 노엘 조 #<b>영화미나리</b> #미나리결말 #<b>영화미나리</b>결말... (영화에서 뇌졸증을 의조증이라고 표현 함) 이사오고 첫 손님으로 폴을 초대해 저녁식사를 하고, 폴은 그... ', 'bloggername': '1Day 1Movie', 'bloggerlink': 'https://blog.naver.com/seotaijiyg', 'postdate': '20210422'}
# 13 {'title': '여우조연상 수상(캡처) “축하! 축하! 축하!” ※<b>영화 미나리</b>', 'link': 'https://blog.naver.com/humanity5844?Redirect=Log&logNo=222323383695', 'description': '영화 평론가 이동진 분은 <b>영화 미나리</b>를 이렇게 평가했습니다. “미나리라는 단어가 흡사 간절한 기도문처럼 들린다.” 영화를 본 저로서는 이 말이 가장 마음에 와닿았고, 짙은 여운과 함께 그분들의... ', 'bloggername': '긍정이랑 희망이랑', 'bloggerlink': 'https://blog.naver.com/humanity5844', 'postdate': '20210426'}
# 14 {'title': '<b>영화 미나리</b> 후기 - 스포 많아요', 'link': 'https://blog.naver.com/cheimh?Redirect=Log&logNo=222327205363', 'description': '그리고 또 <b>미나리</b>처럼 생명력 강하게 다시 일어서는 내공 강한 한국인.. ㅠ 잔잔하게 인상적인 <b>영화</b>였습니다. 어쩌면 가장 일반적인 가족의 모습이었어요 가족을 위해 희생하고, 위기를 겪고, 그렇지만 다시... ', 'bloggername': '악마토끼의 달큰한 유혹~♡', 'bloggerlink': 'https://blog.naver.com/cheimh', 'postdate': '20210429'}
# 15 {'title': '<b>영화</b> 《<b>미나리</b>》에 나타난 아름다운 화합', 'link': 'https://blog.naver.com/sesami9?Redirect=Log&logNo=222354656303', 'description': '《미나리》는 한국인을 다룬 영화지만 사실 한국 영화는 아니다. 브래드 피트의 제작사 플랜B가 제작을 맡고 정이삭 감독과 배우 스티븐 연 등 한국계 미국인들이 만들었기 때문이다. 그래서 <b>영화 미나리</b>에... ', 'bloggername': '행복한 번역가', 'bloggerlink': 'https://blog.naver.com/sesami9', 'postdate': '20210517'}
# 16 {'title': '[이송희일의 <b>영화</b>직설] 당신의 <b>미나리</b>는 원더풀합니까?', 'link': 'https://blog.naver.com/kkangjong?Redirect=Log&logNo=222358343739', 'description': '“가족의 이민사를 인류 보편의 삶으로 일궈냈고, 사는 곳이 달라도 모두 긴밀하게 연결돼 있다는 것을 확인해줬다.” <b>영화</b> &lt; #<b>미나리</b>&gt;가 재현한 한국인의 #미국 #이민사는 ‘인류 보편의 삶’이라는 이야기다.... ', 'bloggername': "'악한 평화는 없고 좋은 전쟁은 없다'", 'bloggerlink': 'https://blog.naver.com/kkangjong', 'postdate': '20210521'}
# 17 {'title': '짜파구리와 <b>영화 미나리</b> 배우 윤여정 아카데미 여우조연상 수상... ', 'link': 'https://blog.naver.com/mobile8889?Redirect=Log&logNo=222362309017', 'description': '동네 청과물 가게에 물어보니 한 단에 3000원. <b>영화</b>의 화제와는 별개로 <b>미나리</b> 가격은 오르지 않았다고 한다. 조선일보 21. 4. 28 짜파구리와 <b>미나리</b> (조선일보 [기자의 視角], 21. 4. 28 A30면)', 'bloggername': '꽃보다 소소한 여유 & 향기있는 이야기들', 'bloggerlink': 'https://blog.naver.com/mobile8889', 'postdate': '20210523'}
# 18 {'title': '[<b>영화</b>] <b>미나리</b>, Minari / 2020 / 감독 정이삭 / 스티븐 연... ', 'link': 'https://blog.naver.com/imagineing?Redirect=Log&logNo=222360217085', 'description': '<b>영화</b> &lt;<b>미나리</b>, Minari / 2020&gt; Trailer 출처 : A24 (YouTube) #영화 #영화후기 #영화리뷰 #영화추천 #추천영화 #영화블로그 #MOVIE #영화감상 #죽기전에봐야할영화 #죽기전에꼭봐야할<b>영화</b> #<b>미나리</b> #2020 #2020년영화 #정이삭... ', 'bloggername': '안녕하세요 ♥', 'bloggerlink': 'https://blog.naver.com/imagineing', 'postdate': '20210521'}
# 19 {'title': '<b>영화 미나리</b> 후기 :: 고요히 바라보는 가보지 않은 세상의 삶', 'link': 'https://blog.naver.com/jangym23?Redirect=Log&logNo=222328034985', 'description': '<b>영화</b> 속 <b>미나리</b>로 상징되는 그 시대 이민자들의 삶. 척박한 곳에서도 그들의 씨앗을 뿌리며 지켜냈을 것들을 상상하게 되는 <b>영화</b>였다. 사실 상황은 좀 달라도, 지금도 척박하고 막연한 곳을 달리고 있을 많은... ', 'bloggername': '모모록', 'bloggerlink': 'https://blog.naver.com/jangym23', 'postdate': '20210429'}
# 20 {'title': '<b>미나리</b> <b>영화</b> 를 보고 나서...', 'link': 'https://blog.naver.com/juliemam511?Redirect=Log&logNo=222310892697', 'description': '근무가 일찍 끝났다 <b>영화 미나리</b>를 보러가야겠다 ㅋㅋ 혼자 뭐가 좋은지 행복을 느끼며 집으로 향했다... 뿌려두었던 미나리는 아무 돌봄없이도 무럭 무럭 잘 자랐다 난 이 영화를 보면서 같은 동질감때문에... ', 'bloggername': '지햄성이의 제주도 일주하기', 'bloggerlink': 'https://blog.naver.com/juliemam511', 'postdate': '20210415'}
# 21 {'title': '[가정의 달 <b>영화</b> 추천] 가족과 함께 볼 가족 <b>영화</b> 추천!(<b>미나리</b>... ', 'link': 'https://blog.naver.com/daliboni?Redirect=Log&logNo=222362333996', 'description': '첫번째 <b>영화</b>는 <b>미나리</b>입니다! <b>미나리</b>는 윤여정님의 오스카상을 수상한 엄청난 작품으로 세계가 인정한 <b>영화</b>라고 할 수 있죠:) 2021년 03월 03일에 개봉하려 누적 관객수는 112만명이랍니다! &lt;줄거리&gt; &quot;<b>미나리</b>는... ', 'bloggername': '영상물등급위원회 공식블로그', 'bloggerlink': 'https://blog.naver.com/daliboni', 'postdate': '20210523'}
# 22 {'title': '[수다톡톡] <b>영화</b> &lt;<b>미나리</b>&gt; 리뷰', 'link': 'https://blog.naver.com/mokwon_univ?Redirect=Log&logNo=222329657563', 'description': '[수다톡톡] <b>영화</b> &lt;<b>미나리</b>&gt; 리뷰 여러분 안녕하세요! 다들 한 주 잘 보내셨나요? 얼마 전, 아카데미 시상식에서 <b>영화</b> &lt;<b>미나리</b>&gt; ‘순자’ 역을 맡은 배우 윤여정님이 여우 조연상을 받아 큰 화제가 되었죠! 한국인... ', 'bloggername': '맞춤 인재를 양성하는 교육혁신대학 - 목원대학교', 'bloggerlink': 'https://blog.naver.com/mokwon_univ', 'postdate': '20210501'}
# 23 {'title': "<b>영화</b> '<b>미나리</b>' 윤여정", 'link': 'https://blog.naver.com/karma_612?Redirect=Log&logNo=222347944089', 'description': '너네 나라는 그래서 간염이 많다….&quot; <b>영화</b> ‘<b>미나리</b>’(3일 개봉)에서 한국 할머니 순자를 연기한 윤여정(74)의 말이다. 미국에 이민 간 딸 모니카(한예리)를 찾아간 순자가 어린 손자 데이빗(앨런 김)에게 삶은... ', 'bloggername': '느낌표를 찾아서..', 'bloggerlink': 'https://blog.naver.com/karma_612', 'postdate': '20210512'}
# 24 {'title': '정이삭 감독 <b>영화 미나리</b>의 장작 골든글로브 보이콧', 'link': 'https://blog.naver.com/luckymasiwoo?Redirect=Log&logNo=222347824048', 'description': '여기에 <b>영화</b> &lt;<b>미나리</b>&gt;가 기름 역할을 톡톡히 합니다. 논란이 걷잡을 수 없자 HFPA는 개혁안을 내놓습니다. 오는 8월까지 새로운 회장을 선임하고, 흑인을 포함한 신규 회원 20명을 추가하겠다는 것. 이에 주간... ', 'bloggername': '마시우가 영화 본다', 'bloggerlink': 'https://blog.naver.com/luckymasiwoo', 'postdate': '20210512'}
# 25 {'title': "<b>영화</b> '<b>미나리</b>' 결말, 할머니 병 그리고 라이프 고즈 온", 'link': 'https://blog.naver.com/namnaraum?Redirect=Log&logNo=222337681910', 'description': "<b>영화</b> '<b>미나리</b>' 결말, 할머니 병 그리고 라이프 고즈 온 본지는 좀 됐는데 이제야 쓰는 '미나리' 리뷰. 우선 윤여정 배우님 미국 아카데미 시상식, 오스카를 비롯한 많은 영화제의 여우조연상 수상을 축하드립니다... ", 'bloggername': '남다른 남나르', 'bloggerlink': 'https://blog.naver.com/namnaraum', 'postdate': '20210504'}
# 26 {'title': '93회 2021 아카데미 시상식 수상 결과 <b>영화 미나리</b> 윤여정', 'link': 'https://blog.naver.com/entombed?Redirect=Log&logNo=222323555200', 'description': '브래드피트 제작으로 아마 피트도 이 <b>영화</b>를 응원하겠죠. <b>미나리</b>는 골든글로브에서는 외국어 <b>영화</b>상만 수상했고. 영국 아카데미에서는 <b>미나리</b> 윤여정 배우는 여우조연상 수상했습니다. 93회 2021 아카데미... ', 'bloggername': '오늘도 걷는다........', 'bloggerlink': 'https://blog.naver.com/entombed', 'postdate': '20210426'}
# 27 {'title': '<b>미나리</b> <b>영화</b> 관람후기 / 윤여정 오스카 수상기념', 'link': 'https://blog.naver.com/moonz?Redirect=Log&logNo=222332901890', 'description': 'ㅜ 주말인데 극장에 사람은 딸랑 2명 봤음 결국 영화관내에서 저 혼자 미나리를 봤답니다. 코로나 여파가 크다지만 이 정도일줄은... 5월 1일자 메가박스 상영표 <b>영화 미나리</b> 이외에 비와 당신의 이야기 더 스파이... ', 'bloggername': '영어쌤의 기억법', 'bloggerlink': 'https://blog.naver.com/moonz', 'postdate': '20210502'}
# 28 {'title': '최신개봉<b>영화</b> 순위 더 스파이 <b>미나리</b> 내일의 기억', 'link': 'https://blog.naver.com/dongi0508?Redirect=Log&logNo=222347108089', 'description': '최신개봉영화 순위 더 스파이 미나리 내일의 기억 요즘에 극장을 안가본지 꽤나 되어서 가고싶은 맘... 애니메이션영화라서 기회가 되면 꼭 보도록 하겠습니다ㅠ <b>영화 미나리</b>도 여전히 인기가 많다. 한동안... ', 'bloggername': 'Der Sinn des Lebens', 'bloggerlink': 'https://blog.naver.com/dongi0508', 'postdate': '20210512'}
# 29 {'title': '<b>영화 미나리</b> (Minari) 2021', 'link': 'https://blog.naver.com/jijjang77?Redirect=Log&logNo=222324992680', 'description': '영화 소개 시작하니 빨리 따라와주세요! 출처 : 네이버 <b>영화 미나리</b> 미나리, 응? 나물? 이라고 생각하시는 분들 꽤나 있으실거에요. 그리고 그 흔한 가족영화 또는 지루한 가족영화라고 생각하실 수도 있으실... ', 'bloggername': 'Favorite,지으니', 'bloggerlink': 'https://blog.naver.com/jijjang77', 'postdate': '20210427'}
# 30 {'title': "&quot;전 세계 열광&quot; <b>영화</b> '<b>미나리</b>' 촬영한 이곳의 정체", 'link': 'https://blog.naver.com/the_trip?Redirect=Log&logNo=222270974313', 'description': '이미지 출처 = 네이버 영화 <b>영화</b> ‘<b>미나리</b>’의 행보가 심상치 않다. 9일(현지시간) 영국 아카데미 시상식(BAFTA) 측의 발표에 따르면 ‘미나리’는 외국어영화상, 감독상, 각본상, 캐스팅상 등 6개 부문... ', 'bloggername': '네이버 여행+', 'bloggerlink': 'https://blog.naver.com/the_trip', 'postdate': '20210310'}
# 31 {'title': '<b>영화 미나리</b> 결말 줄거리 후기 미나리 할머니 윤여정의 그랜마... ', 'link': 'https://blog.naver.com/imagetech1?Redirect=Log&logNo=222340782834', 'description': '후기, 미나리 브레드피트 영화 제작사 플랜비 Plan B사와 관련한 포스팅했습니다. -<b>영화 미나리</b> 결말 줄거리 후기 미나리 브레드피트 영화 동영상 보기 #<b>영화</b>_<b>미나리</b>_결말 #<b>영화</b>_<b>미나리</b>_줄거리 #<b>영화</b>_<b>미나리</b>_후기', 'bloggername': '정연아 이미지테크', 'bloggerlink': 'https://blog.naver.com/imagetech1', 'postdate': '20210506'}
# 32 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt;: 뿌리내림에 대하여', 'link': 'https://blog.naver.com/iwasachild?Redirect=Log&logNo=222345703541', 'description': '디아스포라가 “흩뿌리거나 퍼트리는 것”을 뜻하는 단어에서 유래했다는 사실은 <b>영화</b> &lt;<b>미나리</b>&gt;에서 미나리가 상징하는 바와 일맥상통한다. 영화에서 순자는 한국에서 가져온 미나리 씨앗을 딸의 가족이 살고... ', 'bloggername': 'As You Like It !', 'bloggerlink': 'https://blog.naver.com/iwasachild', 'postdate': '20210510'}
# 33 {'title': '<b>영화 미나리</b>: 미나리는 가족영화에서 택하기 쉬운 이분법적인... ', 'link': 'https://blog.naver.com/sadmad?Redirect=Log&logNo=222344953979', 'description': '<b>미나리</b>는 가족<b>영화</b>에서 택하기 쉬운 이분법적인 전개를 선택하지 않는다. 매일 거대 십자가를 짊어지고 흙길을 걸어가는 폴과 같이 굳이 어려운 길을 택하면서 가족이란 (흔한 미디어가 가족을 그려내는... ', 'bloggername': 'Robination', 'bloggerlink': 'https://blog.naver.com/sadmad', 'postdate': '20210510'}
# 34 {'title': "배우 윤여정 <b>영화</b> '<b>미나리</b>'로 93회 아카데미 여우조연상 수상", 'link': 'https://blog.naver.com/dbtjsdy?Redirect=Log&logNo=222323355831', 'description': "이번 아키데미 시상식에는 한국계 미국인 정이삭 감독이 연출한 <b>영화</b> '<b>미나리</b>가' 6개 부문 후보에 올라... 윤여정 씨는 그동안 <b>영화 미나리</b>로 마흔 개에 가까운 연기상을 수상했습니다. 특히 아카데미의... ", 'bloggername': '사노라면', 'bloggerlink': 'https://blog.naver.com/dbtjsdy', 'postdate': '20210426'}
# 35 {'title': '[<b>영화</b>리뷰] <b>미나리</b> (Minari, 2020)', 'link': 'https://blog.naver.com/soulmater_?Redirect=Log&logNo=222340733675', 'description': '<b>영화 미나리</b> 줄거리와 리뷰가 궁금하시다면 지금부터 집중해주세요. 미나리 영화의 줄거리는? Minari, 2020 낯선 미국, 아칸소로 떠나온 한국 가족. 가족들에게 뭔가 해내는 걸 보여주고 싶은 아빠 제이콥(스티븐... ', 'bloggername': '영화를 말하다', 'bloggerlink': 'https://blog.naver.com/soulmater_', 'postdate': '20210506'}
# 36 {'title': '[<b>영화</b>리뷰] <b>미나리</b> : 밋밋한 <b>영화</b>!', 'link': 'https://blog.naver.com/nongsae?Redirect=Log&logNo=222358326981', 'description': "성주문화예술회관에서 요즘 엄청 이슈가 되고 있는 <b>영화</b> '<b>미나리</b>'를 상영한다고 하여, 도대체 어떤 영화인가싶어 함 봤다. 줄거리를 요약해보겠다. 1. 한인 신혼부부가 땅을 사서 외지로 이사간다. 신랑이 병아리... ", 'bloggername': '인생의 참맛(성주 믿음부동산)', 'bloggerlink': 'https://blog.naver.com/nongsae', 'postdate': '20210520'}
# 37 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt; : 향수에 향이 있다면.. 미나리와 같은 향이 아닐까', 'link': 'https://blog.naver.com/true4753?Redirect=Log&logNo=222341877302', 'description': "솔직히 아예 공감하지 못하는 건 아니지만, 그녀의 연기'만'을 바라보는 것이 아니라 <b>영화</b> &lt;<b>미나리</b>&gt; 속의 순자를 바라본다면, 영화 속 순자는 조연이라고 하지만 사실 그녀를 중심으로 이야기가 만들어지고 더... ", 'bloggername': '추억이 될 오늘에게 感.중진담', 'bloggerlink': 'https://blog.naver.com/true4753', 'postdate': '20210507'}
# 38 {'title': '<b>영화 미나리</b> - 가족, 구원의 basic unit에 관하여', 'link': 'https://blog.naver.com/lovisred_?Redirect=Log&logNo=222322144888', 'description': '드디어 <b>영화 미나리</b>를 보았네요 ~~~ 미나리 감독 정이삭 출연 윌 패튼, 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조 개봉 2021. 03. 03. 요즘 <b>영화 미나리</b>의 성공으로 국내외에서 떠들석 하지요. 여러 영화제에서 많은... ', 'bloggername': '엄마의사', 'bloggerlink': 'https://blog.naver.com/lovisred_', 'postdate': '20210425'}
# 39 {'title': '2021 : 011 / <b>영화</b>, <b>미나리</b>', 'link': 'https://blog.naver.com/chbadafx?Redirect=Log&logNo=222362013666', 'description': "<b>영화</b> [<b>미나리</b>]는 산 넘어 산에 심은 미나리가 겨우겨우 뿌리내리기까지를 보여주는 신기한 미국영화이자 당연한 한국영화다. <b>영화</b> [<b>미나리</b>]에서 할머니가 외친 '원더풀'은 한국인들에게 더 잘 들리는 응원이자... ", 'bloggername': 'PurpleMADE', 'bloggerlink': 'https://blog.naver.com/chbadafx', 'postdate': '20210523'}
# 40 {'title': '<b>영화</b> -<b>미나리</b>(Minari, 2020)', 'link': 'https://blog.naver.com/evergreen122?Redirect=Log&logNo=222322922758', 'description': "요즘 화제작인 <b>영화</b> '<b>미나리</b>'가 웨이브에 올라왔다는 소식을 보고 딸과 함께 미나리를 봤어요. 80년대 미국으로 이민 간 가족들이 겪는 이야기. 감독의 자전적인 이야기라고 합니다. 크게 울리거나 웃기거나... ", 'bloggername': '배꽃 하얗게 피던 날', 'bloggerlink': 'https://blog.naver.com/evergreen122', 'postdate': '20210425'}
# 41 {'title': '억지스러운 설정 없는 잔잔한 감동, <b>영화</b> &lt;<b>미나리</b>&gt;; 스포없는... ', 'link': 'https://blog.naver.com/satin0093?Redirect=Log&logNo=222330804079', 'description': '가족 기대를 많이 하고 봐도 기대 없이 봐도 기분 좋은 감동을 줄 <b>영화</b> &lt;<b>미나리</b>&gt; 과한 설정 없고 캐스팅에 연기 구멍도 없어 영화 내내 미소를 지으며 보실 거예요~ 꼭 한 번 보시길! #<b>영화미나리</b>... ', 'bloggername': '바이올린하는 여자, 산책하는 남자', 'bloggerlink': 'https://blog.naver.com/satin0093', 'postdate': '20210501'}
# 42 {'title': '[<b>영화</b>]<b>미나리</b>(Minari 2020)', 'link': 'https://blog.naver.com/violet0315?Redirect=Log&logNo=222336805044', 'description': "뉴스에서 '윤며들다'라는 타이틀로 <b>미나리</b>라는 <b>영화</b>를 통해 윤여정이 아카데미 여우조연상을 받았다는 소식을 보다가 <b>영화</b>를 찾아보게 됬다. 남자 배우는 워킹데드로 익숙한 스티븐 연과 역시 얼굴이 익숙한... ", 'bloggername': '..', 'bloggerlink': 'https://blog.naver.com/violet0315', 'postdate': '20210504'}
# 43 {'title': '<b>영화 미나리</b>', 'link': 'https://blog.naver.com/namast?Redirect=Log&logNo=222341649504', 'description': '아카데미 여우조연상을 수상한 <b>영화 미나리</b>를 봤습니다. 다큐같은 영화라는 생각이 들었습니다. 영화... 영화속 등장인물들 모두 수채화속 인물처럼 잔잔하게 묘사되고 개울가에 피어난 미나리처럼 가꿔져서... ', 'bloggername': '유후정한의원', 'bloggerlink': 'https://blog.naver.com/namast', 'postdate': '20210507'}
# 44 {'title': '[오늘일기 챌린지 3] 난 시작도 못 했는데 끝인가, <b>영화 미나리</b>', 'link': 'https://blog.naver.com/firey88?Redirect=Log&logNo=222336246981', 'description': '<b>영화 미나리</b>를 보다 이번 미국 아카데미 시상식에서 한국에 첫 여우조연상 수상자가 된 윤여정 배우 때문에 요즘 핫한 <b>영화 미나리</b> 처음에는 무슨 이런 이상한 제목의 영화가 있나 싶었는데 개봉하자마자... ', 'bloggername': '소소한 일상이 쌓이다', 'bloggerlink': 'https://blog.naver.com/firey88', 'postdate': '20210503'}
# 45 {'title': '[<b>영화</b>리뷰] 재미교포 1세들의 잔잔한 이야기 :  <b>미나리</b>', 'link': 'https://blog.naver.com/jmzzang210?Redirect=Log&logNo=222322878007', 'description': '[영화리뷰] 재미교포 1세들의 잔잔한 이야기 미나리 오늘 리뷰할 영화는 최근 아카데미 시상식 여우주연상 후보로 윤여정이 오른 <b>영화</b>, <b>미나리</b>입니다. 내일 (2021.04.26) 시상식이 있죠?! 과연 어떤결과가 나올지... ', 'bloggername': '밤톨맘의 육아 이야기', 'bloggerlink': 'https://blog.naver.com/jmzzang210', 'postdate': '20210425'}
# 46 {'title': '[기고] 조유안, <b>미나리</b>! ‘쉼표 같은 <b>영화</b>’', 'link': 'https://blog.naver.com/nkj1966?Redirect=Log&logNo=222350585518', 'description': '<b>영화</b> ‘<b>미나리</b>’는 1980년대 미국 남부 ‘아칸소’주 작은 시골마을에 한국인 가족이 이사 오며 시작된다. 차에서 내린 가족 앞에 보이는 것이라곤 허허벌판 그리고 트레일러하우스라고 불리는 바퀴 달린 긴... ', 'bloggername': '골드미디어', 'bloggerlink': 'https://blog.naver.com/nkj1966', 'postdate': '20210514'}
# 47 {'title': '<b>영화</b> 리뷰/ <b>미나리</b> (Minari, 2021)', 'link': 'https://blog.naver.com/ekzmepqmf7?Redirect=Log&logNo=222333904541', 'description': '라 한다면 그러진 못할.... 거 같지만(ㅎㅎ) 영화를 보고나서 몇가지 장면이나 대사들이 문득 문득 떠오르던 <b>영화</b>, <b>미나리</b>. 3월 초에 본 거 이제야 기록... ㅎ1히....☆ 아무튼, 원더풀 미나리~~~~~~~', 'bloggername': 'Another day of 에너지원', 'bloggerlink': 'https://blog.naver.com/ekzmepqmf7', 'postdate': '20210502'}
# 48 {'title': "<b>영화</b> '<b>미나리</b>' 첫 장면, 첫 대사는 누구?", 'link': 'https://blog.naver.com/land9944?Redirect=Log&logNo=222327010475', 'description': "일 ~ 미나리의 첫 장면 데이빗 최근 윤여정 씨의 '<b>영화 미나리</b>' 오스카 여우조연상 수상으로 연일... &quot;지금의 정이삭 감독의 심장은 건강한가요?&quot; 한국계 미국인 정이삭 감독의 자전적 <b>영화</b> '<b>미나리</b>'는 윤여정... ", 'bloggername': 'Discovery춘천부동산', 'bloggerlink': 'https://blog.naver.com/land9944', 'postdate': '20210429'}
# 49 {'title': '롯데시네마 김포공항점에서 <b>영화</b> &lt;<b>미나리</b>&gt; 보고 눈물 펑펑', 'link': 'https://blog.naver.com/khu_fullmoon?Redirect=Log&logNo=222333801007', 'description': '#블챌 #오늘일기 2일차 오랜만에, 그리고 남친과는 처음으로 함께 본 <b>영화</b> &lt;<b>미나리</b>&gt;. 평점 8.33으로 다소 낮은 편이었지만 좋아하는 배우들의 출연, 윤여정 배우의 아카데미 여우조연상 수상으로 이미 작품에 대한... ', 'bloggername': '풀문의 다이나믹 라이프', 'bloggerlink': 'https://blog.naver.com/khu_fullmoon', 'postdate': '20210502'}
# 50 {'title': '<b>영화 미나리</b> 배우 윤여정 수상소감과 국내 영어교육', 'link': 'https://blog.naver.com/deusos?Redirect=Log&logNo=222310948080', 'description': '<b>영화 미나리</b> 배우 윤여정 수상소감과 국내 영어교육 재치 있는 수상소감으로 연일 화제가 되고 있는... 영화제에서 해외 현지 관객들을 만나 영어로 대화를 나누는 모습을 보이기도 했고, 현지 매체와의... ', 'bloggername': '공터영어 공식 블로그', 'bloggerlink': 'https://blog.naver.com/deusos', 'postdate': '20210415'}
# 51 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt; : 가족이라는 종교와 이민자들을 위한 동화', 'link': 'https://blog.naver.com/nicemonk?Redirect=Log&logNo=222325558164', 'description': '<b>영화</b> &lt;<b>미나리</b>&gt;를 보면서 떠올린 사람이 둘 있다. 아버지의 할머니(나에겐 증조할머니), 그리고 내 외할머니 김복희 여사. 평안남도 순천에서도 산골 깡촌에 살았던 할아버지는 똥구멍이 찢어지게 가난한... ', 'bloggername': '타자 치는 snoopy', 'bloggerlink': 'https://blog.naver.com/nicemonk', 'postdate': '20210428'}
# 52 {'title': '<b>영화 미나리</b> / 윤여정 여우조연상?', 'link': 'https://blog.naver.com/32day32?Redirect=Log&logNo=222353698969', 'description': '<b>영화 미나리</b>. 대딩백수딸랑구와 초대형청개구리랑 셋이서 함안작은영화관 1관을 통째로 빌려서 봤다. ㅋㅋㅋ 그 시각 우리 뿐이었다. 영화 배경지 미국 아칸소주. 딸랑구가 잠시 놀다온 동네라 어찌 생겼는지... ', 'bloggername': '시인과농부', 'bloggerlink': 'https://blog.naver.com/32day32', 'postdate': '20210516'}
# 53 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt; 속 병아리 감별사, 진짜로 있는 직업일까?', 'link': 'https://blog.naver.com/molab_suda?Redirect=Log&logNo=222349627983', 'description': '아카데미에서 수상하고 각종 해외 영화제를 휩쓸며 또 다시 K-무비의 명성을 드높이고 있는 <b>영화</b> &lt;<b>미나리</b>&gt;. 영화에 등장하는 독특한 직업이 있습니다. 바로 배우 스티븐 연과 한예리가 맡은 직업인 병아리... ', 'bloggername': '고용노동부 공식 블로그', 'bloggerlink': 'https://blog.naver.com/molab_suda', 'postdate': '20210514'}
# 54 {'title': "<b>영화</b> '<b>미나리</b>'를 보고서", 'link': 'https://blog.naver.com/yosupia?Redirect=Log&logNo=222336846978', 'description': "모처럼 웅천으로 '<b>미나리</b>' <b>영화</b>를 보러갔다. 코로나19 때문에 좀처럼 찾지 않았던 <b>영화</b>관이다. 윤여정 배우가 미국 <b>영화</b> 아카데미상에서 우리나라 배우로는 처음으로 여자배우 조연상을 받으면서 더는 안보고... ", 'bloggername': '똑소리닷컴', 'bloggerlink': 'https://blog.naver.com/yosupia', 'postdate': '20210504'}
# 55 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt; 후기, 흔들리지 않고 피는 꽃이 어디 있으랴', 'link': 'https://blog.naver.com/dahamida?Redirect=Log&logNo=222263253925', 'description': '<b>영화</b> &lt;<b>미나리</b>&gt;는 낯설고 투박한 것투성이다. 그래서 더 시대반영적이고 순수하게 느껴진다. 예비 관객들을 위해 알리건대 작품성은 훌륭하지만 오락성(재미) 있는 영화는 아니다. 그러나 시대상과 민족성을 잘... ', 'bloggername': '문화 소믈리에', 'bloggerlink': 'https://blog.naver.com/dahamida', 'postdate': '20210303'}
# 56 {'title': "'알칸서주 여행 이야기'-{이주붐-알칸서주, <b>영화 미나리</b>... ", 'link': 'https://blog.naver.com/keeock?Redirect=Log&logNo=222355221380', 'description': "필자는, 초원이 넓은 오클라호마주에 정착하지 않았다면, Central of Akansa에 Benton이나 Conway에 정착했을 것 같고, 이주하고 싶은 생각이 물신 들정도 였다.' 알칸서는 최근 화제의 <b>영화</b> &quot;<b>미나리</b>&quot;의 배경지... ", 'bloggername': 'Spring Tree in 미국일상', 'bloggerlink': 'https://blog.naver.com/keeock', 'postdate': '20210518'}
# 57 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt; 후기', 'link': 'https://blog.naver.com/ofo330?Redirect=Log&logNo=222338616341', 'description': '미나리 감독 정이삭 출연 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조, 윌 패튼 개봉 2020 미국 블로그 챌린지는 망했지만(...) <b>영화</b> &lt;<b>미나리</b>&gt; 후기를 쓰려구 한다. 현 남자친구는 시네필이다. 영화를 존니 좋아한다.... ', 'bloggername': '세상에 나쁜 냠냠이는 없다', 'bloggerlink': 'https://blog.naver.com/ofo330', 'postdate': '20210505'}
# 58 {'title': '<b>영화 미나리</b> (정이삭)', 'link': 'https://blog.naver.com/hla9865?Redirect=Log&logNo=222325469856', 'description': '그런 게 좀 거슬리긴 했지만 <b>영화</b> 내용도 썩 그저 그랬기 때문에 여러모로 아쉬웠다. <b>미나리</b> 감독 정이삭 출연 윌 패튼, 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조 개봉 2021. 03. 03. 일단 오스카에서 큰 상을... ', 'bloggername': '마음섬', 'bloggerlink': 'https://blog.naver.com/hla9865', 'postdate': '20210427'}
# 59 {'title': '오늘일기 2021.5.2_ <b>영화 미나리</b> &amp; 시어머니', 'link': 'https://blog.naver.com/000naya?Redirect=Log&logNo=222333375610', 'description': '영화를 보며 내내 어머님이 오버랩 되었다. 사실 집(가정사!)의 이야기를 하지 않는데 #<b>영화미나리</b> 의 영향인지. 오늘의 일기를 써야해서 그런지... 한토막 꺼내보았다.', 'bloggername': '베리크래프트(berrycraft)', 'bloggerlink': 'https://blog.naver.com/000naya', 'postdate': '20210502'}
# 60 {'title': '[영어번역] <b>영화</b> ‘<b>미나리</b>’가 우리에게 남긴 여운', 'link': 'https://blog.naver.com/ktri8888?Redirect=Log&logNo=222341415514', 'description': '오늘은 지난주를 뜨겁게 달구었던 오스카 여우조연상에 빛나는 윤여정 배우의 수상소감과 더불어 여전히 핫한 <b>영화</b> &lt;<b>미나리</b>(Minari)&gt;의 명대사도 몇 가지 함께 살펴보고 싶어서... ', 'bloggername': '한국번역연구소', 'bloggerlink': 'https://blog.naver.com/ktri8888', 'postdate': '20210507'}
# 61 {'title': '<b>영화 미나리</b>를 보다', 'link': 'https://blog.naver.com/hansakdsn?Redirect=Log&logNo=222354153367', 'description': '배우 윤여정 씨가 아카데미 조연상을 받았다 하니 호기심에 본 <b>영화</b>다. <b>미나리</b>에서 윤여정 씨 연기가 아카데미 여우 조연상을 받을 정도일까? 나는 잘 모르겠다. <b>영화</b> 속 윤여정 씨 연기 중 가장 인상 깊은 씬은... ', 'bloggername': '한사의 서재', 'bloggerlink': 'https://blog.naver.com/hansakdsn', 'postdate': '20210517'}
# 62 {'title': '<b>영화 미나리</b>를 보고', 'link': 'https://blog.naver.com/ravemst?Redirect=Log&logNo=222324039672', 'description': '미나리 감독 정이삭 출연 윌 패튼, 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조 개봉 2021. 03. 03. 이민자의 삶 <b>영화 미나리</b>는 잔잔하고 평이하게 흘러가는 섬세한 이야기다. 분명 재미없어할 사람들이 많을... ', 'bloggername': 'Frog in Corea', 'bloggerlink': 'https://blog.naver.com/ravemst', 'postdate': '20210426'}
# 63 {'title': "<b>영화 미나리</b> 속 '순자'와 우리 엄마 '순자'", 'link': 'https://blog.naver.com/dgwff?Redirect=Log&logNo=222355700378', 'description': '출처-네이버 <b>영화</b> 『<b>미나리</b>』는 한국 이주민으로 아메리칸 드림이야기 같은 소재를 넘어 결코... <b>영화 미나리</b> 속 순자가 &quot;미나리는 어디서든 잘 자라&quot;라는 말의 시작으로 사위인 제이콥이 &quot;할머니께서 자리를 참... ', 'bloggername': '대구여성가족재단 나다움', 'bloggerlink': 'https://blog.naver.com/dgwff', 'postdate': '20210518'}
# 64 {'title': '<b>영화 미나리</b>...그후가 궁금', 'link': 'https://blog.naver.com/happysh29?Redirect=Log&logNo=222356412927', 'description': '꿈이라는 농장주또한 최초의 꿈은 아니었으리라 생각된다 <b>영화</b>의 결말은 또다른 시작을 해야하는 상황에서 끝나지만 할머니가 키운 <b>미나리</b>로 맛있는 음식을 해먹고 끝났으면 하는 개인적인 아쉬움이있다', 'bloggername': 'HAPPY써니♥', 'bloggerlink': 'https://blog.naver.com/happysh29', 'postdate': '20210518'}
# 65 {'title': '방송대) <b>영화</b>산업과 마케팅 (강승구, 장일) 학습과 <b>미나리</b>의 쾌거', 'link': 'https://blog.naver.com/lovseed?Redirect=Log&logNo=222325723138', 'description': '코로나로 영화관에 가기도 쉽지 않아 <b>영화 미나리</b>는 #OTT 플랫폼을 통해 보는 분들이 많을 것 같네요. #중간고사 #과제 를 정리해 보며 앞으로 전개되는 미나리 마케팅을 좀더 흥미롭게 학습해 보아야 겠네요.', 'bloggername': '道冶 김용재와 이 순간 共感！共有！共生!을 위해', 'bloggerlink': 'https://blog.naver.com/lovseed', 'postdate': '20210428'}
# 66 {'title': '<b>영화 미나리</b> 후기 : 스스로 잘 자라나는 미나리처럼', 'link': 'https://blog.naver.com/bmk7741?Redirect=Log&logNo=222332389150', 'description': '이 영화가 극장에 처음 나왔을때는 관심이 없다가, 윤여정 선생님이 해외의 여러 영화제에서 상을... 수분으로 곱게 가꿔낸, 몸에 좋고 맛도 좋은 힐링 미나리 #윤여정미나리 #미나리감상평 #<b>영화미나리</b>', 'bloggername': '세계를 누비는 봉월리의 이야기!', 'bloggerlink': 'https://blog.naver.com/bmk7741', 'postdate': '20210502'}
# 67 {'title': '[<b>영화</b>] <b>미나리</b> / 구원은 어디에 있을까?', 'link': 'https://blog.naver.com/danicole?Redirect=Log&logNo=222343616254', 'description': "작년에는 '기생충'이 <b>영화</b>계를 떠들썩하게 하더니, 올해는 '<b>미나리</b>'가 그 자리를 대신했다. 매우 상반된 시대적 배경과 분위기의 <b>영화</b>인데 모두 해외 <b>영화</b>제에서 상을 받고, 주목을 받는 점이 흥미롭기도 하고... ", 'bloggername': 'TAM 나는 인재 :D', 'bloggerlink': 'https://blog.naver.com/danicole', 'postdate': '20210509'}
# 68 {'title': '<b>영화 미나리</b> 윤여정 아카데미상 수상 가능성 예측', 'link': 'https://blog.naver.com/ireya?Redirect=Log&logNo=222322756903', 'description': '2021년 아카데미 시상식 (사진 출처 : https://abc.com/) 2020년 초, 봉준호 감독님의 영화 기생충이... #아카데미 #아카데미미나리 #아카데미윤여정 #윤여정 #<b>영화미나리</b> #윤여정아카데미상 #여우조연상... ', 'bloggername': '책과 산에서 길을 잃다', 'bloggerlink': 'https://blog.naver.com/ireya', 'postdate': '20210425'}
# 69 {'title': '[문화공연] 위키드/ 시카고 / <b>영화미나리</b>_', 'link': 'https://blog.naver.com/princessnumb?Redirect=Log&logNo=222363103481', 'description': '이럴때 특히 더 쑥쓰럽다_ 정말 모델이나 연예인은 아무나 하는것이 아닌것 같다_ 그사이 이번에 상을 완전히 휩쓴 <b>영화 미나리</b>_ CGV송파로 갔는데, 관객은 많지 않았고, 예전엔 주차가 무료였던거 같은데... ', 'bloggername': '반짝반짝 빛나는 ☆', 'bloggerlink': 'https://blog.naver.com/princessnumb', 'postdate': '20210523'}
# 70 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt;에 사용된 DaVinci Resolve', 'link': 'https://blog.naver.com/laizenti?Redirect=Log&logNo=222324199018', 'description': '(보도자료) 미국 캘리포니아, 프레몬트 – 2021년 4월 22일(목) - Blackmagic Design은 오늘 아카데미 후보에 오른 <b>영화</b> &lt;<b>미나리</b>&gt;의 색보정에 FotoKem사의 수석 컬러리스트 데이비드 콜(David Cole)이 DaVinci Resolve를... ', 'bloggername': '으랏차의 디지털 랩', 'bloggerlink': 'https://blog.naver.com/laizenti', 'postdate': '20210426'}
# 71 {'title': "김해문화의 전당에서 <b>영화</b> '<b>미나리</b>' 상영", 'link': 'https://blog.naver.com/ghhamohamo?Redirect=Log&logNo=222265126245', 'description': "<b>영화 미나리</b> 포스터 <b>영화</b> '<b>미나리</b>'의 스토리 &quot;미나리는 어디서든 잘 자라&quot; 낯선 미국, 아칸소로 떠나온 한국 가족이 있다. 가족들에게 뭔가 보여주고 싶은 아빠'제이콥'은 자신만의 농장을 가꾸기 시작하고, 엄마... ", 'bloggername': '김해관광공식블로그', 'bloggerlink': 'https://blog.naver.com/ghhamohamo', 'postdate': '20210305'}
# 72 {'title': '<b>영화</b> &quot;<b>미나리</b>&quot; - 물과 불과 부활', 'link': 'https://blog.naver.com/dankedu?Redirect=Log&logNo=222324492127', 'description': '없느니라” <b>영화 미나리</b>는 아름다운 영화다. 넓게 펼쳐진 푸른 초원, 잔잔한 음악, 따사로운 햇빛... 그 물은 미나리가 자라는 냇가에서 길러온 물이다. 물이 그의 복잡한 머리를 씻어준다. “세례”의 이미지다.... ', 'bloggername': '사랑하는 이에게', 'bloggerlink': 'https://blog.naver.com/dankedu', 'postdate': '20210427'}
# 73 {'title': 'DaVinci Resolve 사례 <b>영화</b> &quot;<b>미나리</b>&quot;의 경우(번역)', 'link': 'https://blog.naver.com/1967jk?Redirect=Log&logNo=222320491674', 'description': 'DaVinci Resolve 사례 <b>영화</b> &quot;<b>미나리</b>&quot;의 경우 Photo by Josh Ethan Johnson , Courtesy of A24 Blackmagic Design의 발표에 따르면 아카데미상 후보 작품 미나리가 Foto Kem의 시니어 컬러리스트 데이비드 콜에 의해 DaVinci Resolve... ', 'bloggername': '촬영감독 나종광', 'bloggerlink': 'https://blog.naver.com/1967jk', 'postdate': '20210423'}
# 74 {'title': '<b>영화 미나리</b> 한 번쯤 꼭 봐야 하는 이유', 'link': 'https://blog.naver.com/luvpoetry?Redirect=Log&logNo=222313771736', 'description': "<b>영화 미나리</b> 정보 장르 : 드라마 감독 : 정이삭 개봉 : 2020. 03. 03. 출연 : 한예리, 스티븐 연, 윤여정, 앨런... <b>영화</b> &lt;<b>미나리</b>&gt;에 등장하는 이 가족의 직업은 '병아리 감별사'였는데요. 사람마다 생각하는 것이 다를 순... ", 'bloggername': '이상의 영화여행', 'bloggerlink': 'https://blog.naver.com/luvpoetry', 'postdate': '20210417'}
# 75 {'title': '<b>영화 미나리</b> 관련주 주가 분석 및 전망 체크!', 'link': 'https://blog.naver.com/madld?Redirect=Log&logNo=222268092931', 'description': '이미 많은 상을 받고있는 미나리 주식인으로서 그리고 영화를 좋아하는 사람으로서 여러모로 기대되는 영화입니다. 이상 <b>영화 미나리</b> 관련주 sm life design이었습니다. ★ 개인적인 견해의 글입니다. 절대... ', 'bloggername': '기록하는 공간', 'bloggerlink': 'https://blog.naver.com/madld', 'postdate': '20210308'}
# 76 {'title': '영화 명대사, 캘리그라피로 쓴 <b>영화 미나리</b> 속 명대사', 'link': 'https://blog.naver.com/kkjs7002?Redirect=Log&logNo=222325145527', 'description': '캘리그라피 글씨 연습을 어떤 주제로 할까 고민하다 뉴스를 보고 생각나서 써 본 <b>영화 미나리</b> 명대사. 한국인의 위상을 높게 세워준 영화라서 쓰는 내내 자랑스러웠고 영광스럽기까지 했어요. 원더풀 미나리!... ', 'bloggername': '알밤캘리', 'bloggerlink': 'https://blog.naver.com/kkjs7002', 'postdate': '20210427'}
# 77 {'title': '<b>영화</b> “<b>미나리</b>”에서 보여지는 한국 이민자의 모습은 과연... ', 'link': 'https://blog.naver.com/nickykim156423?Redirect=Log&logNo=222334299282', 'description': '진행되는 <b>영화</b> “<b>미나리</b>”에서 보여지는 한국 이민자의 모습은 과연 어떤 것일까요? 한국 이민자 가족의 고된 생존 투쟁을 그린 <b>영화 미나리</b>는 1980년대를 시대 배경으로 하고 있지만, 실제로 한국인들이 미국... ', 'bloggername': 'Nicky Kim 블로그', 'bloggerlink': 'https://blog.naver.com/nickykim156423', 'postdate': '20210503'}
# 78 {'title': '<b>영화 미나리</b>를 봤습니다. 映画 ミナリを見ました', 'link': 'https://blog.naver.com/yumiko46?Redirect=Log&logNo=222355524590', 'description': '#미나리 #<b>영화미나리</b> #줄거리미포함 #영화추천 #映画ミナリ 、출처 네이버 *줄거리 없어요.안심하고 읽으세요^^ 今、韓国で一番話題の映画であるミナリを見ました。 기생충을 봤을 때도 이건 한국영화 아닌것... ', 'bloggername': '암튼 조아 !', 'bloggerlink': 'https://blog.naver.com/yumiko46', 'postdate': '20210518'}
# 79 {'title': '[<b>영화</b>] <b>미나리</b> 레인송(Rain Song)_귓가를 맴도는', 'link': 'https://blog.naver.com/kunchangdayo?Redirect=Log&logNo=222326030577', 'description': '#레인송 반복해서 계속 들은 노래, 귓가를 맴돈다 영화 끝에 나온 노래 Rain Song <b>영화</b> ‘<b>미나리</b>’의 끝은 쓸쓸하다. 할리우드의 전형을 따르지 않았기 때문이다. 관객은 그럼에도 주인공 가족들이 다시 꿈을... ', 'bloggername': '마음울림연구소', 'bloggerlink': 'https://blog.naver.com/kunchangdayo', 'postdate': '20210428'}
# 80 {'title': '[성인 강남 영어과외] <b>영화 미나리</b>에 감동한 코난... ', 'link': 'https://blog.naver.com/tobemaven?Redirect=Log&logNo=222326301928', 'description': "-<b>영화 미나리</b>에 감동한 코난 &amp; 스티븐연 대화- -And this is a movie that really is about a family. -하지만 이 영화는 정말 가족에 관한 것이고 -Yeah. -그렇죠. -And a family that's in a very, it's an immigrant... ", 'bloggername': '다니엘 영어 팩토리', 'bloggerlink': 'https://blog.naver.com/tobemaven', 'postdate': '20210428'}
# 81 {'title': '5/3 <b>영화 미나리</b> 감상문', 'link': 'https://blog.naver.com/vmfflvmffl?Redirect=Log&logNo=222333370983', 'description': '#블챌 #오늘일기 #<b>영화미나리</b> #미나리감상평 #미나리감상 #미나리감상문 오늘은 <b>영화 미나리</b>를 봤다... 화낼때도 한국영화에서의 분노보다 좀더 부드러운느낌. 아래 스포있음 &quot;남자는 쓸모가 없어. 그래서 쓸모가... ', 'bloggername': '높은 산', 'bloggerlink': 'https://blog.naver.com/vmfflvmffl', 'postdate': '20210502'}
# 82 {'title': '(영화) 한국 <b>영화 미나리</b> 감상하기 (요약 : 9분6초)- 장곡 이석이', 'link': 'https://blog.naver.com/dan1600?Redirect=Log&logNo=222339064027', 'description': '(영화) 한국 <b>영화 미나리</b> 감상하기 (요약 : 9분 6초) - 장곡 이석이 https://m.youtube.com/watch?v=yvO1hxwr7hA... 한극 <b>영화</b>. <b>미나리</b> 를 감상해 보세요. - 장곡 이석이 저는 현재 산골마을에 살고 있지만, 한 때는... ', 'bloggername': '청정지역에서친환경농임업을실현하는강소농 장곡농원', 'bloggerlink': 'https://blog.naver.com/dan1600', 'postdate': '20210505'}
# 83 {'title': '<b>영화</b>, <b>미나리</b>', 'link': 'https://blog.naver.com/iriver720?Redirect=Log&logNo=222353417759', 'description': '비오는 휴일, <b>영화 미나리</b>를 봤다 미나리 감독 정이삭 출연 윌 패튼, 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조 개봉 2021.03.03. - 때로 아슬아슬, 위태롭게 낯선 미국, 아칸소로 떠나온 한국 가족. 가족들에게... ', 'bloggername': '모나코의 초록향기', 'bloggerlink': 'https://blog.naver.com/iriver720', 'postdate': '20210516'}
# 84 {'title': '3대가족의 어린이날 이벤트, <b>영화 미나리</b> 함께 보기!', 'link': 'https://blog.naver.com/sukwha73?Redirect=Log&logNo=222339645722', 'description': '<b>영화</b> #<b>미나리</b>를 어린이날 저녁에 온 가족이 다같이 보았다. 여섯 명의 가족이 다같이 모이고 시간을 맞추기가 생각보다 쉽지 않다. 게다가 관심과 흥미의 교집합으로 어필하기도. 해서는 어려서 일찍 자는... ', 'bloggername': '조한종의 일상과 50+스토리 (More Than A 50+ Cafe)', 'bloggerlink': 'https://blog.naver.com/sukwha73', 'postdate': '20210506'}
# 85 {'title': '#오늘일기_210502_<b>영화 미나리</b> 뒷북 관람, 만보 걷기 운동... ', 'link': 'https://blog.naver.com/orquidia?Redirect=Log&logNo=222333789795', 'description': '[chit-chat] <b>영화 미나리</b> 오늘 아니면 못 볼 것 같아서 어젯밤에 후다닥 예매를 해두었다. 수상 기념 윤여정 기획전으로, 미나리 &amp; 화녀도 개봉. 정이삭 감독의 자전적 영화. 하아... 진짜. 가족 영화 보면 너무... ', 'bloggername': 'Given In Love For Protection', 'bloggerlink': 'https://blog.naver.com/orquidia', 'postdate': '20210502'}
# 86 {'title': '<b>영화 미나리</b>: 어쩌면 의지, 함께하면 되지', 'link': 'https://blog.naver.com/wjhlove777?Redirect=Log&logNo=222327260169', 'description': "되지 <b>영화 미나리</b> ost를 몇일동안 하루종일 틀어놓고 있다. 있는 그대로의 영화라서 그런가, 음악조차... 새로 시작할 수 있다는 삶의 의지를 가르쳐준다. 어디서든 잘 자라는 '미나리'에게서 배운다. #<b>영화미나리</b>", 'bloggername': '가장 확실한 순간의 기록', 'bloggerlink': 'https://blog.naver.com/wjhlove777', 'postdate': '20210429'}
# 87 {'title': '<b>영화</b> &quot;<b>미나리</b>&quot; 봤어요!', 'link': 'https://blog.naver.com/silkyej?Redirect=Log&logNo=222300285321', 'description': '* 저는 빈혈이 있어서 헌혈을 못해요.ㅜ.ㅜ <b>영화</b> &quot;<b>미나리</b>&quot;를 보러 송도 트리플 스트리트로! 인천 1호선을 타고 테크노파크역에서 하차하니 바로 현대 프리미엄 아울렛으로 통하더군요. 쇼핑몰 안쪽을 걷다... ', 'bloggername': 'Lovely Violet', 'bloggerlink': 'https://blog.naver.com/silkyej', 'postdate': '20210406'}
# 88 {'title': "윤여정 배우님 <b>영화</b> '<b>미나리</b>' 화투", 'link': 'https://blog.naver.com/rlagkdus0102?Redirect=Log&logNo=222342287667', 'description': '같이 영화 보러갔었던 친구가 왜이렇게 화투에 갑자기 꽂혔냐고ㅋㅋㅋㅋ 근데 전 화투가 좋은 걸 어떡해요... 아무쪼록 뒤죽박죽 <b>영화 미나리</b> 후기 마칠게요~~ 뿅! #미나리 #<b>영화미나리</b> #윤여정 #오스카 #고스톱... ', 'bloggername': '스칼렛의 꿈꾸는 나무', 'bloggerlink': 'https://blog.naver.com/rlagkdus0102', 'postdate': '20210508'}
# 89 {'title': '<b>영화</b>감상) <b>미나리</b>', 'link': 'https://blog.naver.com/susu0722?Redirect=Log&logNo=222337943747', 'description': '#미나리 #<b>영화미나리</b> 미나리 감독 정이삭 출연 윌 패튼, 스티븐 연, 한예리, 윤여정, 앨런 김, 노엘 조 개봉 2021. 03. 03. 정말 오랜만에 마음잡고 영화를 본것이라서, 기대를 많이했다. 인생... 기대를 하지... ', 'bloggername': '미소테일의 홈라이프', 'bloggerlink': 'https://blog.naver.com/susu0722', 'postdate': '20210504'}
# 90 {'title': '함평극장, 자동차극장, 함평맥시칸치킨, <b>영화미나리</b>', 'link': 'https://blog.naver.com/kjy9873?Redirect=Log&logNo=222334894821', 'description': '점 써져있습니다 ㅎ 무심코 밟은 브레이크에 뒷차 눈뽕 핵 심합니다 ㅋㅋ 영화가 격정적이여도 브레이크는 참아주세욥 ㅋ 맥시칸치킨 닭강정 얼른 오픈 ㅎ 또똣하니 좋네요 ㅎㅎ <b>영화 미나리</b> 를 보게된 ㅎㅎ... ', 'bloggername': '사낚 - 낚시여행', 'bloggerlink': 'https://blog.naver.com/kjy9873', 'postdate': '20210503'}
# 91 {'title': "<b>영화</b> '<b>미나리</b>'의 가족과 실제 가족", 'link': 'https://blog.naver.com/classicandme?Redirect=Log&logNo=222324618048', 'description': "<b>영화</b> '<b>미나리</b>'에서 남아 있던 궁금증들은 각본을 쓰고 연출한 리 아이삭 정(정이삭) 감독의 아버지와 통화하면서 뒤늦게 어느 정도 풀리게 되었습니다. 이제 길거리에 아이를 만나서도 영화... ", 'bloggername': '클래식 네버랜드', 'bloggerlink': 'https://blog.naver.com/classicandme', 'postdate': '20210428'}
# 92 {'title': '[네이버플러스 멤버십] 네이버 포인트 혜택과 <b>영화 미나리</b> 무료... ', 'link': 'https://blog.naver.com/cocochanel38?Redirect=Log&logNo=222324290264', 'description': '#네이버플러스멤버십 #네이버플러스맴버십 #미나리공짜로보기 #네이버플러스멤버십혜택 #영화미나히무료 #<b>영화미나리</b> #미나리무료로보기 #네이버시리즈온 #오스카 #아카데미시상식여우조연상... ', 'bloggername': 'Lpage29', 'bloggerlink': 'https://blog.naver.com/cocochanel38', 'postdate': '20210427'}
# 93 {'title': '<b>영화 미나리</b> 윤여정 배우 아카데미 수상 기념 국내 OTT 영화... ', 'link': 'https://blog.naver.com/putiomelux?Redirect=Log&logNo=222323802967', 'description': "오늘 미국 아카데미 시상식에서 <b>영화</b> '<b>미나리</b>'의 윤여정 배우님이 여우조연상 수상 이라는 쾌거를 달성하셨어요. 너무 축하드립니다 짝짝짝! 수상 소감도 위트있고 너무 멋지게 하셔서 인상깊었고 나이란 정말... ", 'bloggername': '세상을 바라보다.', 'bloggerlink': 'https://blog.naver.com/putiomelux', 'postdate': '20210426'}
# 94 {'title': 'Emile Mosseri &amp; Han Ye-ri - Rain Song (<b>영화 미나리</b> OST 2020)', 'link': 'https://blog.naver.com/zeppelinbar?Redirect=Log&logNo=222323930571', 'description': '오픈송 #미나리ost #윤여정 #아카데미여우조연상 #한예리 #에밀모세리 <b>영화 미나리</b>는 이민자 1세대들의 슬픈과 기쁨을 잘 표현한, 가족을 통해 희망을 전하는 감명 깊은 한편의 드라마 같은 영화입니... ', 'bloggername': '강남 LP바 제플린', 'bloggerlink': 'https://blog.naver.com/zeppelinbar', 'postdate': '20210426'}
# 95 {'title': "<b>영화</b> '<b>미나리</b>'", 'link': 'https://blog.daum.net/yh6950/671', 'description': "<b>영화</b> '<b>미나리</b>' 그렇게나 화제작이었던 <b>영화 미나리</b>.... 매스컴에서 많은 이야기들을 해서 어떤 영화인지 궁굼해서 어제 비오는 날 오후. 혼자서 영화 보기 딱 좋은 날. 난 즐거운 마음으로 집을 나섰다. 집에서... ", 'bloggername': '삶의 여유로움', 'bloggerlink': 'https://blog.daum.net/yh6950', 'postdate': '20210505'}
# 96 {'title': '<b>영화 미나리</b> 아역배우 앨런 김 국적 나이 프로필 키 인스타', 'link': 'https://toobedori.tistory.com/974', 'description': "<b>영화</b> '<b>미나리</b>'의 아역배우 앨런 김(나이는 7세)이 아역상을 품에 안았답니다. '미나리'는 2021년 3월 8일 미국 로스앤젤레스에서 열린 제26회 크리틱스 초이스 어워즈에서 외국어영화상과 더불어서, 아역상을... ", 'bloggername': '뚜비돌이의 세상만사', 'bloggerlink': 'https://toobedori.tistory.com/', 'postdate': '20210420'}
# 97 {'title': "<b>영화</b> '<b>미나리</b>'", 'link': 'https://blog.daum.net/hyeyeun0/15715548', 'description': "작년 말과 올 초 우리나라 사람들 氣를 살려준 <b>영화</b>가 있으니 바로 '<b>미나리</b>'이다. 물론 제작을 우리나라에서 한 것도 아니고 우리나라 자본이 들어간 작품도 아니지만 대부분 한국말로 미국에 이민간 한국 가정을... ", 'bloggername': '솔뫼들', 'bloggerlink': 'https://blog.daum.net/hyeyeun0', 'postdate': '20210415'}
# 98 {'title': '<b>영화</b> &lt;<b>미나리</b>&gt;', 'link': 'https://blog.daum.net/mr_serious/544', 'description': '<b>영화</b> &lt;<b>미나리</b>&gt;는 한국에선 개봉도 하기 전에 미국과 유럽에서 왠만한 영화제를 휩쓸고 아카데미 수상 후보작이 되고서야 한국에서 개봉을 했다. 지난 3월 3일에 개봉한 이 영화는 코로나의 영향인지 아직 백만... ', 'bloggername': '새미골', 'bloggerlink': 'https://blog.daum.net/mr_serious', 'postdate': '20210419'}
# 99 {'title': '<b>영화</b> &quot;<b>미나리</b>&quot;를 보고서', 'link': 'https://blog.daum.net/garisani/2079', 'description': '<b>영화</b> &quot;<b>미나리</b>&quot;를 보고서 댓글 0 합의된 공감 2021. 3. 26. ↑영화 시작 전. 스크린 양옆 커튼이 접히고 화면 크기가 커지며 영화가 시작한다. 1. 극장은 한발 물러서야 볼 수 있는 세계다. 스크린과 일정 거리를 두어야... ', 'bloggername': '사람이, 사람에게, 사람을 말하다', 'bloggerlink': 'https://blog.daum.net/garisani', 'postdate': '20210326'}

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time as time
import getpass
import urllib.request
import random
 
from time import sleep
 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-logging"])

## headless setting  /  접속하면 user정보가 없어 크롤링을 막기 때문에 가짜 user-agent 등록
options.headless = True
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36")

## GPU 사용X
# options.add_argument("disable-gpu")

## 언어 = 한글
options.add_argument('lang=ko_KR')


driver = webdriver.Chrome(r"C:\tools\Selenium\chromedriver.exe", options=options) # Chromedriver PATH
driver.get("https://www.instagram.com/accounts/login/")
# driver.maximize_window()
print('드라이버 구동 완료')

# username = getpass.getpass("Input ID : ")      # User ID
username = '01022606785'              

# password = getpass.getpass("Input PWD : ")  # User PWD,  getpass를 통해서 비밀번호 정보를 숨길 수도 있다.
password = 'tr7cfglku12e!@'   


hashTag = input("Input HashTag # : ")# Search #
print("========== 로그인 정보 입력 완료 ==========")

element_id = driver.find_element_by_name("username")
element_id.send_keys(username)         # 개발시 별도의 로그인 계정 확보 필
element_password = driver.find_element_by_name("password")
element_password.send_keys(password)        # 개발시 별도의 로그인 계정 확보 필    
sleep(2)

##로그인버튼 클릭
driver.find_element_by_css_selector('.sqdOP.L3NKy.y3zKF').click()
sleep(2)

## 로그인 정보 저장 관련 
#승인
# driver.find_element_by_css_selector('.sqdOP.L3NKy.y3zKF').click()
#거부
driver.find_element_by_css_selector('.sqdOP.yWX7d.y3zKF').click()

## 검색할 해쉬의 주소
driver.get(insta_searching(hashTag))  
sleep(2)

print('==================검색 완료=================')


##데이터를 저장할 Dictionary
insta_dict = {'id':[],
              'date': [],
              'text': [],
              'hashtag':[]}
 
 
## 첫 번째 게시물 클릭 
first_post = driver.find_element_by_class_name('eLAPa')
first_post.click()
sleep(2)


seq = 0
start = time.time()
 
while True:
    try:
        if driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow'):
            if seq % 20 == 0:
                print('{}번째 수집 중 / 진행시간 :'.format(seq), time.time() - start, sep = '\t')
  
            ## id 정보 수집
            try:
                info_id = driver.find_element_by_css_selector('h2._6lAjh').text
                insta_dict['id'].append(info_id)
            except:
                info_id = driver.find_element_by_css_selector('div.C4VMK').text.split()[0]
                insta_dict['id'].append(info_id)
 
            ## 시간정보 수집 
            time_raw = driver.find_element_by_css_selector('time.FH9sR.Nzb55')
            time_info = pd.to_datetime(time_raw.get_attribute('datetime')).normalize()
            insta_dict['date'].append(time_info)
 
            ##text 정보수집
            raw_info = driver.find_element_by_css_selector('div.C4VMK').text.split()
            text = []
            for i in range(len(raw_info)):
                ## 첫번째 text는 아이디니까 제외 
                if i == 0:
                    pass
                ## 두번째부터 시작
                else:
                    if '#' in raw_info[i]:
                        pass
                    else:
                        text.append(raw_info[i])
            clean_text = ' '.join(text)
            insta_dict['text'].append(clean_text)
 
            ##hashtag 수집
            raw_tags = driver.find_elements_by_css_selector('a.xil3i')
            hash_tag = []
            for i in range(len(raw_tags)):
                if raw_tags[i].text == '':
                    pass
                else:
                    hash_tag.append(raw_tags[i].text)
 
            insta_dict['hashtag'].append(hash_tag)
 
            seq += 1
            if seq == 100:
                break
 
            driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow').click()
            time.sleep(1.5)
        else:
            break
    except:
        print("ID or PW error")
        driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow').click()
        time.sleep(2)

print("=============", len(insta_dict['text']), '건의 자료를 수집했습니다.')
print(insta_dict)
# Out:
# 드라이버 구동 완료
# Input ID : ········
# Input PWD : ········
# 01022606785
# tr7cfglku12e!@
# Input HashTag # : 영화 미나리
# ========== 로그인 정보 입력 완료 ==========
# ==================검색 완료=================
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-3-3ed1076cd7b0> in <module>
#      74
#      75 # 게시물 선택
# ---> 76 first_post = driver.find_element_by_class_name('eLAPa')
#      77 first_post.click()
#      78 sleep(2)
#
# c:\users\kjong\anaconda3\envs\nlp\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\kjong\anaconda3\envs\nlp\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# c:\users\kjong\anaconda3\envs\nlp\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\kjong\anaconda3\envs\nlp\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".eLAPa"}
#   (Session info: headless chrome=90.0.4430.212)
